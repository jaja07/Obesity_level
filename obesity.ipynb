# %% [markdown]
# Import du dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
data = fetch_ucirepo(id=544) 
  
# data (as pandas dataframes) 
X = data.data.features 
y = data.data.targets 
  
# metadata 
print(data.metadata) 
  
# variable information 
print(data.variables)
# Out:
# {'uci_id': 544, 'name': 'Estimation of Obesity Levels Based On Eating Habits and Physical Condition ', 'repository_url': 'https://archive.ics.uci.edu/dataset/544/estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition', 'data_url': 'https://archive.ics.uci.edu/static/public/544/data.csv', 'abstract': 'This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition. ', 'area': 'Health and Medicine', 'tasks': ['Classification', 'Regression', 'Clustering'], 'characteristics': ['Multivariate'], 'num_instances': 2111, 'num_features': 16, 'feature_types': ['Integer'], 'demographics': ['Gender', 'Age'], 'target_col': ['NObeyesdad'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2019, 'last_updated': 'Mon Feb 26 2024', 'dataset_doi': '10.24432/C5H31Z', 'creators': [], 'intro_paper': {'title': 'Dataset for estimation of obesity levels based on eating habits and physical condition in individuals from Colombia, Peru and Mexico', 'authors': 'Fabio Mendoza Palechor, Alexis De la Hoz Manotas', 'published_in': 'Data in Brief', 'year': 2019, 'url': 'https://www.semanticscholar.org/paper/35b40bacd2ffa9370885b7a3004d88995fd1d011', 'doi': '10.1016/j.dib.2019.104344'}, 'additional_info': {'summary': 'This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition. The data contains 17 attributes and 2111 records, the records are labeled with the class variable NObesity (Obesity Level), that allows classification of the data using the values of Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II and Obesity Type III. 77% of the data was generated synthetically using the Weka tool and the SMOTE filter, 23% of the data was collected directly from users through a web platform.', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Read the article (https://doi.org/10.1016/j.dib.2019.104344) to see the description of the attributes.', 'citation': None}}
#                               name     role         type demographic  \
# 0                           Gender  Feature  Categorical      Gender
# 1                              Age  Feature   Continuous         Age
# 2                           Height  Feature   Continuous        None
# 3                           Weight  Feature   Continuous        None
# 4   family_history_with_overweight  Feature       Binary        None
# 5                             FAVC  Feature       Binary        None
# 6                             FCVC  Feature      Integer        None
# 7                              NCP  Feature   Continuous        None
# 8                             CAEC  Feature  Categorical        None
# 9                            SMOKE  Feature       Binary        None
# 10                            CH2O  Feature   Continuous        None
# 11                             SCC  Feature       Binary        None
# 12                             FAF  Feature   Continuous        None
# 13                             TUE  Feature      Integer        None
# 14                            CALC  Feature  Categorical        None
# 15                          MTRANS  Feature  Categorical        None
# 16                      NObeyesdad   Target  Categorical        None
#
#                                           description units missing_values
# 0                                                None  None             no
# 1                                                None  None             no
# 2                                                None  None             no
# 3                                                None  None             no
# 4   Has a family member suffered or suffers from o...  None             no
# 5            Do you eat high caloric food frequently?  None             no
# 6        Do you usually eat vegetables in your meals?  None             no
# 7              How many main meals do you have daily?  None             no
# 8                  Do you eat any food between meals?  None             no
# 9                                       Do you smoke?  None             no
# 10                 How much water do you drink daily?  None             no
# 11         Do you monitor the calories you eat daily?  None             no
# 12           How often do you have physical activity?  None             no
# 13  How much time do you use technological devices...  None             no
# 14                    How often do you drink alcohol?  None             no
# 15           Which transportation do you usually use?  None             no
# 16                                      Obesity level  None             no

# %%
X.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS
# 0  Public_Transportation
# 1  Public_Transportation
# 2  Public_Transportation
# 3                Walking
# 4  Public_Transportation

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
# dtypes: float64(8), object(8)
# memory usage: 264.0+ KB

# %%
X.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NObeyesdad  2111 non-null   object
# dtypes: object(1)
# memory usage: 16.6+ KB

# %%
y.value_counts(normalize=True)*100
# Out:
# NObeyesdad
# Obesity_Type_I         16.627191
# Obesity_Type_III       15.348176
# Obesity_Type_II        14.069162
# Overweight_Level_I     13.737565
# Overweight_Level_II    13.737565
# Normal_Weight          13.595452
# Insufficient_Weight    12.884889
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in X[['Gender','family_history_with_overweight','FAVC','CAEC','SMOKE','SCC','CALC','MTRANS']].columns:
    #print(column)
    X[column] = le.fit_transform(X[column])
# Out:
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])
# C:\Users\jarfi\AppData\Local\Temp\ipykernel_26836\3913380901.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = le.fit_transform(X[column])

# %%
X = X.rename(columns={'Gender': 'Gender',
                       'Age': 'Age',
                       'Height': 'Height',
                       'Weight': 'Weight',
                       'family_history_with_overweight': 'family_history_with_overweight',
                       'FAVC': 'high_caloric_food',
                       'FCVC': 'vegetables_meals',
                       'NCP': 'main_meals_daily',
                       'CAEC': 'eat_btw_meals',
                       'SMOKE': 'SMOKE',
                       'CH2O': 'CH2O',
                       'SCC': 'monitor_calories',
                       'FAF': 'physical_activity',
                       'TUE': 'tech_time',
                       'CALC': 'alcohol_frequency',
                       'MTRANS': 'MTRANS'})

# %%
X.head()
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  \
# 0       0  21.0    1.62    64.0                               1
# 1       0  21.0    1.52    56.0                               1
# 2       1  23.0    1.80    77.0                               1
# 3       1  27.0    1.80    87.0                               0
# 4       1  22.0    1.78    89.8                               0
#
#    high_caloric_food  vegetables_meals  main_meals_daily  eat_btw_meals  \
# 0                  0               2.0               3.0              2
# 1                  0               3.0               3.0              2
# 2                  0               2.0               3.0              2
# 3                  0               3.0               3.0              2
# 4                  0               2.0               1.0              2
#
#    SMOKE  CH2O  monitor_calories  physical_activity  tech_time  \
# 0      0   2.0                 0                0.0        1.0
# 1      1   3.0                 1                3.0        0.0
# 2      0   2.0                 0                2.0        1.0
# 3      0   2.0                 0                2.0        0.0
# 4      0   2.0                 0                0.0        0.0
#
#    alcohol_frequency  MTRANS
# 0                  3       3
# 1                  2       3
# 2                  1       3
# 3                  1       4
# 4                  2       3

# %%
dataset = X
dataset['Obesity_level'] = y
dataset['Obesity_level'] = dataset['Obesity_level'].map(
    {
        'Obesity_Type_I': 0,
        'Obesity_Type_III':1,
        'Obesity_Type_II':2,
        'Overweight_Level_I':3,
        'Overweight_Level_II':4,
        'Normal_Weight':5,
        'Insufficient_Weight':6
        
    }
)

# %%
#Affichage des graphiques
dataset.hist(bins=50, figsize=(12, 12))
plt.show()

# %%
dataset['Obesity_level'].value_counts()
# Out:
# Obesity_level
# 0    351
# 1    324
# 2    297
# 3    290
# 4    290
# 5    287
# 6    272
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
heatmap = sns.heatmap(dataset.corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap de la correlation entre les variables')
plt.show()

# %% [markdown]
# Création des ensembles de test et d'entrainement

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset.drop('Obesity_level', axis=1), dataset['Obesity_level'], test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# Sélection du modèle: Notre objectif étant de prédire le type d'obésité d'une personne, il s'agit alors d'un problème de classification. Nous allons choisir entre trois modèles de classification: Random forest, SVM et KNN

# %% [markdown]
# Arbre de décision

# %%
# instanciation de l'arbre
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
# dictionnaire des hyperparamètres
search_space = {
    'criterion':['gini','entropy','log_loss']
}

# Initialisation de GridSearchCV
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=tree, param_grid = search_space, cv=5, scoring = "accuracy", verbose = 4)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ....................criterion=gini;, score=0.920 total time=   0.0s
# [CV 2/5] END ....................criterion=gini;, score=0.941 total time=   0.0s
# [CV 3/5] END ....................criterion=gini;, score=0.923 total time=   0.0s
# [CV 4/5] END ....................criterion=gini;, score=0.970 total time=   0.0s
# [CV 5/5] END ....................criterion=gini;, score=0.920 total time=   0.0s
# [CV 1/5] END .................criterion=entropy;, score=0.941 total time=   0.0s
# [CV 2/5] END .................criterion=entropy;, score=0.938 total time=   0.0s
# [CV 3/5] END .................criterion=entropy;, score=0.956 total time=   0.0s
# [CV 4/5] END .................criterion=entropy;, score=0.953 total time=   0.0s
# [CV 5/5] END .................criterion=entropy;, score=0.926 total time=   0.0s
# [CV 1/5] END ................criterion=log_loss;, score=0.944 total time=   0.0s
# [CV 2/5] END ................criterion=log_loss;, score=0.944 total time=   0.0s
# [CV 3/5] END ................criterion=log_loss;, score=0.953 total time=   0.0s
# [CV 4/5] END ................criterion=log_loss;, score=0.950 total time=   0.0s
# [CV 5/5] END ................criterion=log_loss;, score=0.938 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss']},
#              scoring='accuracy', verbose=4)

# %%
print(grid_search.best_estimator_) # pour avoir les détail du meilleur modèle
# Out:
# DecisionTreeClassifier(criterion='log_loss')

# %%
best_tree = DecisionTreeClassifier(criterion='log_loss',max_depth=7)
best_tree.fit(X_train,y_train)
best_tree.score(X_test, y_test)
# Out:
# 0.9314420803782506

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,20))
plot_tree(best_tree, feature_names= list(dataset.columns[:-1]),  filled=True)
plt.show()

# %%
names = y.value_counts().index.tolist()
type(names)
type(names[0][0])
# Out:
# str

# %% [markdown]
# Méthodes ensemblistes: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(bootstrap=True)
# dictionnaire des hyperparamètres
search_space_rf = {
    'criterion':['gini','entropy','log_loss'],
    'n_estimators':[10,50,70,100,150,200]
}

# Initialisation de GridSearchCV
grid_search_rf = GridSearchCV(estimator= rf_clf, param_grid = search_space_rf, cv=5, scoring = "accuracy", verbose = 4)
grid_search_rf.fit(X_train, y_train)
print(grid_search.best_estimator_) # pour avoir les détails du meilleur modèle
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END ...criterion=gini, n_estimators=10;, score=0.923 total time=   0.0s
# [CV 2/5] END ...criterion=gini, n_estimators=10;, score=0.917 total time=   0.0s
# [CV 3/5] END ...criterion=gini, n_estimators=10;, score=0.935 total time=   0.0s
# [CV 4/5] END ...criterion=gini, n_estimators=10;, score=0.941 total time=   0.0s
# [CV 5/5] END ...criterion=gini, n_estimators=10;, score=0.911 total time=   0.0s
# [CV 1/5] END ...criterion=gini, n_estimators=50;, score=0.929 total time=   0.1s
# [CV 2/5] END ...criterion=gini, n_estimators=50;, score=0.953 total time=   0.0s
# [CV 3/5] END ...criterion=gini, n_estimators=50;, score=0.973 total time=   0.1s
# [CV 4/5] END ...criterion=gini, n_estimators=50;, score=0.953 total time=   0.1s
# [CV 5/5] END ...criterion=gini, n_estimators=50;, score=0.932 total time=   0.1s
# [CV 1/5] END ...criterion=gini, n_estimators=70;, score=0.926 total time=   0.1s
# [CV 2/5] END ...criterion=gini, n_estimators=70;, score=0.959 total time=   0.1s
# [CV 3/5] END ...criterion=gini, n_estimators=70;, score=0.959 total time=   0.1s
# [CV 4/5] END ...criterion=gini, n_estimators=70;, score=0.961 total time=   0.1s
# [CV 5/5] END ...criterion=gini, n_estimators=70;, score=0.953 total time=   0.1s
# [CV 1/5] END ..criterion=gini, n_estimators=100;, score=0.938 total time=   0.2s
# [CV 2/5] END ..criterion=gini, n_estimators=100;, score=0.953 total time=   0.2s
# [CV 3/5] END ..criterion=gini, n_estimators=100;, score=0.959 total time=   0.2s
# [CV 4/5] END ..criterion=gini, n_estimators=100;, score=0.953 total time=   0.2s
# [CV 5/5] END ..criterion=gini, n_estimators=100;, score=0.955 total time=   0.2s
# [CV 1/5] END ..criterion=gini, n_estimators=150;, score=0.926 total time=   0.3s
# [CV 2/5] END ..criterion=gini, n_estimators=150;, score=0.947 total time=   0.4s
# [CV 3/5] END ..criterion=gini, n_estimators=150;, score=0.959 total time=   0.4s
# [CV 4/5] END ..criterion=gini, n_estimators=150;, score=0.950 total time=   0.3s
# [CV 5/5] END ..criterion=gini, n_estimators=150;, score=0.955 total time=   0.4s
# [CV 1/5] END ..criterion=gini, n_estimators=200;, score=0.929 total time=   0.5s
# [CV 2/5] END ..criterion=gini, n_estimators=200;, score=0.959 total time=   0.5s
# [CV 3/5] END ..criterion=gini, n_estimators=200;, score=0.962 total time=   0.5s
# [CV 4/5] END ..criterion=gini, n_estimators=200;, score=0.950 total time=   0.5s
# [CV 5/5] END ..criterion=gini, n_estimators=200;, score=0.955 total time=   0.5s
# [CV 1/5] END criterion=entropy, n_estimators=10;, score=0.914 total time=   0.0s
# [CV 2/5] END criterion=entropy, n_estimators=10;, score=0.947 total time=   0.0s
# [CV 3/5] END criterion=entropy, n_estimators=10;, score=0.959 total time=   0.0s
# [CV 4/5] END criterion=entropy, n_estimators=10;, score=0.929 total time=   0.0s
# [CV 5/5] END criterion=entropy, n_estimators=10;, score=0.914 total time=   0.0s
# [CV 1/5] END criterion=entropy, n_estimators=50;, score=0.938 total time=   0.1s
# [CV 2/5] END criterion=entropy, n_estimators=50;, score=0.947 total time=   0.1s
# [CV 3/5] END criterion=entropy, n_estimators=50;, score=0.970 total time=   0.1s
# [CV 4/5] END criterion=entropy, n_estimators=50;, score=0.944 total time=   0.1s
# [CV 5/5] END criterion=entropy, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 1/5] END criterion=entropy, n_estimators=70;, score=0.926 total time=   0.2s
# [CV 2/5] END criterion=entropy, n_estimators=70;, score=0.950 total time=   0.2s
# [CV 3/5] END criterion=entropy, n_estimators=70;, score=0.962 total time=   0.2s
# [CV 4/5] END criterion=entropy, n_estimators=70;, score=0.958 total time=   0.2s
# [CV 5/5] END criterion=entropy, n_estimators=70;, score=0.961 total time=   0.2s
# [CV 1/5] END criterion=entropy, n_estimators=100;, score=0.935 total time=   0.3s
# [CV 2/5] END criterion=entropy, n_estimators=100;, score=0.947 total time=   0.3s
# [CV 3/5] END criterion=entropy, n_estimators=100;, score=0.959 total time=   0.3s
# [CV 4/5] END criterion=entropy, n_estimators=100;, score=0.947 total time=   0.3s
# [CV 5/5] END criterion=entropy, n_estimators=100;, score=0.955 total time=   0.3s
# [CV 1/5] END criterion=entropy, n_estimators=150;, score=0.941 total time=   0.5s
# [CV 2/5] END criterion=entropy, n_estimators=150;, score=0.956 total time=   0.5s
# [CV 3/5] END criterion=entropy, n_estimators=150;, score=0.953 total time=   0.5s
# [CV 4/5] END criterion=entropy, n_estimators=150;, score=0.958 total time=   0.5s
# [CV 5/5] END criterion=entropy, n_estimators=150;, score=0.953 total time=   0.5s
# [CV 1/5] END criterion=entropy, n_estimators=200;, score=0.944 total time=   0.8s
# [CV 2/5] END criterion=entropy, n_estimators=200;, score=0.950 total time=   0.8s
# [CV 3/5] END criterion=entropy, n_estimators=200;, score=0.962 total time=   0.9s
# [CV 4/5] END criterion=entropy, n_estimators=200;, score=0.958 total time=   0.7s
# [CV 5/5] END criterion=entropy, n_estimators=200;, score=0.955 total time=   0.7s
# [CV 1/5] END criterion=log_loss, n_estimators=10;, score=0.896 total time=   0.0s
# [CV 2/5] END criterion=log_loss, n_estimators=10;, score=0.935 total time=   0.0s
# [CV 3/5] END criterion=log_loss, n_estimators=10;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=log_loss, n_estimators=10;, score=0.926 total time=   0.0s
# [CV 5/5] END criterion=log_loss, n_estimators=10;, score=0.911 total time=   0.0s
# [CV 1/5] END criterion=log_loss, n_estimators=50;, score=0.944 total time=   0.1s
# [CV 2/5] END criterion=log_loss, n_estimators=50;, score=0.967 total time=   0.1s
# [CV 3/5] END criterion=log_loss, n_estimators=50;, score=0.962 total time=   0.1s
# [CV 4/5] END criterion=log_loss, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 5/5] END criterion=log_loss, n_estimators=50;, score=0.929 total time=   0.1s
# [CV 1/5] END criterion=log_loss, n_estimators=70;, score=0.953 total time=   0.2s
# [CV 2/5] END criterion=log_loss, n_estimators=70;, score=0.950 total time=   0.2s
# [CV 3/5] END criterion=log_loss, n_estimators=70;, score=0.953 total time=   0.2s
# [CV 4/5] END criterion=log_loss, n_estimators=70;, score=0.955 total time=   0.2s
# [CV 5/5] END criterion=log_loss, n_estimators=70;, score=0.947 total time=   0.2s
# [CV 1/5] END criterion=log_loss, n_estimators=100;, score=0.935 total time=   0.3s
# [CV 2/5] END criterion=log_loss, n_estimators=100;, score=0.956 total time=   0.3s
# [CV 3/5] END criterion=log_loss, n_estimators=100;, score=0.956 total time=   0.3s
# [CV 4/5] END criterion=log_loss, n_estimators=100;, score=0.955 total time=   0.3s
# [CV 5/5] END criterion=log_loss, n_estimators=100;, score=0.953 total time=   0.3s
# [CV 1/5] END criterion=log_loss, n_estimators=150;, score=0.929 total time=   0.5s
# [CV 2/5] END criterion=log_loss, n_estimators=150;, score=0.953 total time=   0.5s
# [CV 3/5] END criterion=log_loss, n_estimators=150;, score=0.956 total time=   0.5s
# [CV 4/5] END criterion=log_loss, n_estimators=150;, score=0.950 total time=   0.5s
# [CV 5/5] END criterion=log_loss, n_estimators=150;, score=0.950 total time=   0.5s
# [CV 1/5] END criterion=log_loss, n_estimators=200;, score=0.932 total time=   0.7s
# [CV 2/5] END criterion=log_loss, n_estimators=200;, score=0.953 total time=   0.7s
# [CV 3/5] END criterion=log_loss, n_estimators=200;, score=0.964 total time=   0.7s
# [CV 4/5] END criterion=log_loss, n_estimators=200;, score=0.955 total time=   0.7s
# [CV 5/5] END criterion=log_loss, n_estimators=200;, score=0.955 total time=   0.7s
# DecisionTreeClassifier(criterion='log_loss')

# %%
print(grid_search.best_params_,grid_search.best_score_) # pour avoir les détail du meilleur modèle
# Out:
# {'criterion': 'log_loss'} 0.9454954084947238

# %%
best_rf_clf = RandomForestClassifier(criterion='log_loss', bootstrap=True, n_estimators=100)
best_rf_clf.fit(X_train,y_train)
best_rf_clf.score(X_test, y_test)
# Out:
# 0.9574468085106383
